# %%
import pandas
import pickle
import json
from tqdm import tqdm_notebook
from pandas.io.json import json_normalize

# %%
teamleads = pickle.load(open("teamleads", "rb"))

# %%
developers = pickle.load(open("developers", "rb"))

# %%
new_developers = pickle.load(open("new_developers", "rb"))

# %%
def calculate_personal_mentor_possibility(person):
    if (person['wantmentee'] == 1 and len(person['menteeid'].split(', ')) < person['maxmentee']):
        mentor_possibility = person['currentcompanyexperience'] * 0.2 + person['overalexperience'] * 0.1 + person['mentorscore'] * 0.05 - person['ismentor'] * 0.05
    else:
        mentor_possibility = 0
    return mentor_possibility

# %%
def calculate_mentor_possibility(mentee, mentor):
    if (mentee['ismentee'] == 1):
        return 0
    if (mentee['department'] != mentor['department']):
        return 0
    if (mentee['id'] == mentor['id']):
        return 0
    
    if mentee['codinglanguages'] == '':
        lang_mathing = 2
    else:
        lang_mathing = 0
        tee_langs = mentee['codinglanguages'].split(', ')
        tor_langs = mentor['codinglanguages']
        for i in tee_langs:
            if i in tor_langs:
                lang_mathing += 1

    institute_matching = 0
    tee_institutes = mentee['institutes'].split(', ')
    tor_institutes = mentor['institutes']
    for i in tee_institutes:
        if i in tor_institutes:
            institute_matching += 1
            break
            
    age_diff = abs(mentor['age'] - mentee['age'])
    
    return calculate_personal_mentor_possibility(mentor) + 0.1 * lang_mathing + 0.1 * institute_matching - 0.01 * age_diff

# %%
import numpy as np

# %%
def find_mentors(mentee, mentors, n):
    matches = []
    for i in mentors:
        matches.append(calculate_mentor_possibility(mentee, i))
    maximum = max(matches)
    maximum = max(10, maximum)
    minimum = min(matches)
    matches = [(i - minimum)/(maximum - minimum) for i in matches]
    matches = np.asarray(matches)
    if (n < len(matches)):
    return matches.argsort()[-n:][::-1])

# %%
developers[87]
# Out:
# {'age': 22,
#  'codinglanguages': 'java, python, c#',
#  'currentcompanyexperience': 3,
#  'department': 'development',
#  'id': '78e39644c389559834e6d72f1ca8818a3a5d93d0',
#  'institutes': 'Московский государственный университет им. М.В.Ломоносова',
#  'ismentee': 0,
#  'ismentor': 0,
#  'maxmentee': 3,
#  'menteeid': '',
#  'menteescore': 0,
#  'mentorid': '',
#  'mentorpossibility': 1.6,
#  'mentorscore': 0,
#  'name': 'name78e39644c389559834e6d72f1ca8818a3a5d93d0',
#  'overalexperience': 10,
#  'patronymic': 'patronymic78e39644c389559834e6d72f1ca8818a3a5d93d0',
#  'position': 'developer',
#  'surname': 'surname78e39644c389559834e6d72f1ca8818a3a5d93d0',
#  'wantmentee': 1}

# %%
find_mentors(new_developers[67], developers, 5)
# Out:
# [ 87 173  45  27 132]

# %%
len(new_developers)
# Out:
# 81

# %%
new_developers[0]
# Out:
# {'age': 64,
#  'codinglanguages': '',
#  'currentcompanyexperience': 0,
#  'department': 'development',
#  'id': 'a58c7502a78aefe5d91e6ee844926ab99385ab97',
#  'institutes': 'Московский государственный университет им. М.В. Ломоносова, Национальный исследовательский технологический университет "МИСиС"',
#  'ismentee': 0,
#  'ismentor': 0,
#  'maxmentee': 0,
#  'menteeid': '',
#  'menteescore': 0,
#  'mentorid': '',
#  'mentorscore': 0,
#  'name': 'namea58c7502a78aefe5d91e6ee844926ab99385ab97',
#  'overalexperience': 1,
#  'patronymic': 'patronymica58c7502a78aefe5d91e6ee844926ab99385ab97',
#  'position': 'developer',
#  'surname': 'surnamea58c7502a78aefe5d91e6ee844926ab99385ab97',
#  'wantmentee': 0}

# %%
developers
# Out:
# [{'age': 40,
#   'codinglanguages': 'java, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'c2ccf9a4fcb0387a702af6abea8592c5e37ca7cf',
#   'institutes': 'Финансовый университет при Правительстве РФ, Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'namec2ccf9a4fcb0387a702af6abea8592c5e37ca7cf',
#   'overalexperience': 1,
#   'patronymic': 'patronymicc2ccf9a4fcb0387a702af6abea8592c5e37ca7cf',
#   'position': 'developer',
#   'surname': 'surnamec2ccf9a4fcb0387a702af6abea8592c5e37ca7cf',
#   'wantmentee': 1},
#  {'age': 41,
#   'codinglanguages': 'java, c/c++, python, haskell',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '8419b42196ac5b832a38017a7d8311b81a758104',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name8419b42196ac5b832a38017a7d8311b81a758104',
#   'overalexperience': 1,
#   'patronymic': 'patronymic8419b42196ac5b832a38017a7d8311b81a758104',
#   'position': 'developer',
#   'surname': 'surname8419b42196ac5b832a38017a7d8311b81a758104',
#   'wantmentee': 1},
#  {'age': 38,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'e5e8dda129ad6b9e50b329695e5bce3abe53d246',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namee5e8dda129ad6b9e50b329695e5bce3abe53d246',
#   'overalexperience': 0,
#   'patronymic': 'patronymice5e8dda129ad6b9e50b329695e5bce3abe53d246',
#   'position': 'developer',
#   'surname': 'surnamee5e8dda129ad6b9e50b329695e5bce3abe53d246',
#   'wantmentee': 1},
#  {'age': 56,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '9aaef1804d970439441dea3ba2d48e96c0aa8e45',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name9aaef1804d970439441dea3ba2d48e96c0aa8e45',
#   'overalexperience': 0,
#   'patronymic': 'patronymic9aaef1804d970439441dea3ba2d48e96c0aa8e45',
#   'position': 'developer',
#   'surname': 'surname9aaef1804d970439441dea3ba2d48e96c0aa8e45',
#   'wantmentee': 1},
#  {'age': 42,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '9fc15df5251ecfde6968449aec1cef25dfc5d9c5',
#   'institutes': 'Литературный институт имени А.М.Горького, Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name9fc15df5251ecfde6968449aec1cef25dfc5d9c5',
#   'overalexperience': 0,
#   'patronymic': 'patronymic9fc15df5251ecfde6968449aec1cef25dfc5d9c5',
#   'position': 'developer',
#   'surname': 'surname9fc15df5251ecfde6968449aec1cef25dfc5d9c5',
#   'wantmentee': 1},
#  {'age': 34,
#   'codinglanguages': 'java, c/c++, python, c#, haskell',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '11f63220bb5f86288e372228b6dbcacdf0ec578a',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name11f63220bb5f86288e372228b6dbcacdf0ec578a',
#   'overalexperience': 0,
#   'patronymic': 'patronymic11f63220bb5f86288e372228b6dbcacdf0ec578a',
#   'position': 'developer',
#   'surname': 'surname11f63220bb5f86288e372228b6dbcacdf0ec578a',
#   'wantmentee': 1},
#  {'age': 38,
#   'codinglanguages': 'c/c++, 1c, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '6ec34f40e1eaa988a8a84aec67fa43272dc0113a',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова, Московский государственный вечерний металлургический институт',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name6ec34f40e1eaa988a8a84aec67fa43272dc0113a',
#   'overalexperience': 1,
#   'patronymic': 'patronymic6ec34f40e1eaa988a8a84aec67fa43272dc0113a',
#   'position': 'developer',
#   'surname': 'surname6ec34f40e1eaa988a8a84aec67fa43272dc0113a',
#   'wantmentee': 1},
#  {'age': 55,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '5ce98e6d5663d21bdb622e8baf980dd53073ca4c',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ", Национальный исследовательский ядерный университет "МИФИ"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name5ce98e6d5663d21bdb622e8baf980dd53073ca4c',
#   'overalexperience': 1,
#   'patronymic': 'patronymic5ce98e6d5663d21bdb622e8baf980dd53073ca4c',
#   'position': 'developer',
#   'surname': 'surname5ce98e6d5663d21bdb622e8baf980dd53073ca4c',
#   'wantmentee': 1},
#  {'age': 53,
#   'codinglanguages': 'java, c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '3a74d7e8a6cce3e59cbbafd582a154de6420e743',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name3a74d7e8a6cce3e59cbbafd582a154de6420e743',
#   'overalexperience': 0,
#   'patronymic': 'patronymic3a74d7e8a6cce3e59cbbafd582a154de6420e743',
#   'position': 'developer',
#   'surname': 'surname3a74d7e8a6cce3e59cbbafd582a154de6420e743',
#   'wantmentee': 1},
#  {'age': 37,
#   'codinglanguages': 'java, c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '2cf8f918605a38681950e81a63537355e61afa21',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name2cf8f918605a38681950e81a63537355e61afa21',
#   'overalexperience': 1,
#   'patronymic': 'patronymic2cf8f918605a38681950e81a63537355e61afa21',
#   'position': 'developer',
#   'surname': 'surname2cf8f918605a38681950e81a63537355e61afa21',
#   'wantmentee': 1},
#  {'age': 50,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '920fc69fa96203da4cd1ec37c75596d227b4518b',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name920fc69fa96203da4cd1ec37c75596d227b4518b',
#   'overalexperience': 1,
#   'patronymic': 'patronymic920fc69fa96203da4cd1ec37c75596d227b4518b',
#   'position': 'developer',
#   'surname': 'surname920fc69fa96203da4cd1ec37c75596d227b4518b',
#   'wantmentee': 1},
#  {'age': 59,
#   'codinglanguages': 'java, c/c++, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'b7ed41073fa5706637fb3074c14fea9e6afb8d84',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова, Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'nameb7ed41073fa5706637fb3074c14fea9e6afb8d84',
#   'overalexperience': 1,
#   'patronymic': 'patronymicb7ed41073fa5706637fb3074c14fea9e6afb8d84',
#   'position': 'developer',
#   'surname': 'surnameb7ed41073fa5706637fb3074c14fea9e6afb8d84',
#   'wantmentee': 1},
#  {'age': 45,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '10eb9b6c83fdb7c6d20719b8286223a069917638',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name10eb9b6c83fdb7c6d20719b8286223a069917638',
#   'overalexperience': 0,
#   'patronymic': 'patronymic10eb9b6c83fdb7c6d20719b8286223a069917638',
#   'position': 'developer',
#   'surname': 'surname10eb9b6c83fdb7c6d20719b8286223a069917638',
#   'wantmentee': 1},
#  {'age': 34,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '795393a14f5780d713bce0e253c38f834c9eb7f1',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ", Московский Математический Колледж',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name795393a14f5780d713bce0e253c38f834c9eb7f1',
#   'overalexperience': 0,
#   'patronymic': 'patronymic795393a14f5780d713bce0e253c38f834c9eb7f1',
#   'position': 'developer',
#   'surname': 'surname795393a14f5780d713bce0e253c38f834c9eb7f1',
#   'wantmentee': 1},
#  {'age': 50,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'aa6a55186fbb8953f46944f390f862657cc5601e',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'nameaa6a55186fbb8953f46944f390f862657cc5601e',
#   'overalexperience': 0,
#   'patronymic': 'patronymicaa6a55186fbb8953f46944f390f862657cc5601e',
#   'position': 'developer',
#   'surname': 'surnameaa6a55186fbb8953f46944f390f862657cc5601e',
#   'wantmentee': 1},
#  {'age': 32,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'e111717378afcc3e0da3bf34d1c11aa737fc37ff',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namee111717378afcc3e0da3bf34d1c11aa737fc37ff',
#   'overalexperience': 0,
#   'patronymic': 'patronymice111717378afcc3e0da3bf34d1c11aa737fc37ff',
#   'position': 'developer',
#   'surname': 'surnamee111717378afcc3e0da3bf34d1c11aa737fc37ff',
#   'wantmentee': 1},
#  {'age': 29,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '340deaade6163efd29aa88596c7694d72274d477',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name340deaade6163efd29aa88596c7694d72274d477',
#   'overalexperience': 0,
#   'patronymic': 'patronymic340deaade6163efd29aa88596c7694d72274d477',
#   'position': 'developer',
#   'surname': 'surname340deaade6163efd29aa88596c7694d72274d477',
#   'wantmentee': 1},
#  {'age': 40,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'ac0acf63be62f0ec573e8b5805a66ff64e71a42e',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'nameac0acf63be62f0ec573e8b5805a66ff64e71a42e',
#   'overalexperience': 0,
#   'patronymic': 'patronymicac0acf63be62f0ec573e8b5805a66ff64e71a42e',
#   'position': 'developer',
#   'surname': 'surnameac0acf63be62f0ec573e8b5805a66ff64e71a42e',
#   'wantmentee': 1},
#  {'age': 42,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '9c6388d327b5f81f6d21e14e8bde81ff2ad7ba0c',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова, Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name9c6388d327b5f81f6d21e14e8bde81ff2ad7ba0c',
#   'overalexperience': 0,
#   'patronymic': 'patronymic9c6388d327b5f81f6d21e14e8bde81ff2ad7ba0c',
#   'position': 'developer',
#   'surname': 'surname9c6388d327b5f81f6d21e14e8bde81ff2ad7ba0c',
#   'wantmentee': 1},
#  {'age': 38,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '77b28c341d320d5276bf6098147ba67c38f0bda5',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name77b28c341d320d5276bf6098147ba67c38f0bda5',
#   'overalexperience': 0,
#   'patronymic': 'patronymic77b28c341d320d5276bf6098147ba67c38f0bda5',
#   'position': 'developer',
#   'surname': 'surname77b28c341d320d5276bf6098147ba67c38f0bda5',
#   'wantmentee': 1},
#  {'age': 43,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'a83af11fdd4cb8cbd68dc06d8e1e34c697066e8a',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namea83af11fdd4cb8cbd68dc06d8e1e34c697066e8a',
#   'overalexperience': 0,
#   'patronymic': 'patronymica83af11fdd4cb8cbd68dc06d8e1e34c697066e8a',
#   'position': 'developer',
#   'surname': 'surnamea83af11fdd4cb8cbd68dc06d8e1e34c697066e8a',
#   'wantmentee': 1},
#  {'age': 45,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '75b0cf4f997f25995c5911993a175186ea2a623d',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name75b0cf4f997f25995c5911993a175186ea2a623d',
#   'overalexperience': 0,
#   'patronymic': 'patronymic75b0cf4f997f25995c5911993a175186ea2a623d',
#   'position': 'developer',
#   'surname': 'surname75b0cf4f997f25995c5911993a175186ea2a623d',
#   'wantmentee': 1},
#  {'age': 36,
#   'codinglanguages': 'java, c/c++, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '252a5a3cedfcb4ba641c74faf550a894c9c22ac4',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name252a5a3cedfcb4ba641c74faf550a894c9c22ac4',
#   'overalexperience': 0,
#   'patronymic': 'patronymic252a5a3cedfcb4ba641c74faf550a894c9c22ac4',
#   'position': 'developer',
#   'surname': 'surname252a5a3cedfcb4ba641c74faf550a894c9c22ac4',
#   'wantmentee': 1},
#  {'age': 30,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'aab9105df2351bea02fb15dae719e2a7ed29de10',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова, Костромской государственный университет имени Н.А.Некрасова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'nameaab9105df2351bea02fb15dae719e2a7ed29de10',
#   'overalexperience': 0,
#   'patronymic': 'patronymicaab9105df2351bea02fb15dae719e2a7ed29de10',
#   'position': 'developer',
#   'surname': 'surnameaab9105df2351bea02fb15dae719e2a7ed29de10',
#   'wantmentee': 1},
#  {'age': 39,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'bbb26ab9846624d2acfbb70631ea8bdda71180ac',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namebbb26ab9846624d2acfbb70631ea8bdda71180ac',
#   'overalexperience': 0,
#   'patronymic': 'patronymicbbb26ab9846624d2acfbb70631ea8bdda71180ac',
#   'position': 'developer',
#   'surname': 'surnamebbb26ab9846624d2acfbb70631ea8bdda71180ac',
#   'wantmentee': 1},
#  {'age': 29,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '13c630b184f506435e025dd2eccc94975a8028de',
#   'institutes': 'Московский государственный технологический университет "Станкин"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name13c630b184f506435e025dd2eccc94975a8028de',
#   'overalexperience': 1,
#   'patronymic': 'patronymic13c630b184f506435e025dd2eccc94975a8028de',
#   'position': 'developer',
#   'surname': 'surname13c630b184f506435e025dd2eccc94975a8028de',
#   'wantmentee': 1},
#  {'age': 31,
#   'codinglanguages': '1c, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '38485f6df446c8e8677d45a2b58c115ec293be15',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ", Московский государственный колледж информационных технологий',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name38485f6df446c8e8677d45a2b58c115ec293be15',
#   'overalexperience': 1,
#   'patronymic': 'patronymic38485f6df446c8e8677d45a2b58c115ec293be15',
#   'position': 'developer',
#   'surname': 'surname38485f6df446c8e8677d45a2b58c115ec293be15',
#   'wantmentee': 1},
#  {'age': 32,
#   'codinglanguages': 'c/c++, python',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '33172b72d0b17f832aa47d577318b7f00862961e',
#   'institutes': 'Высшая школа Молде, Норвегия, Российский государственный социальный университет, Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.8,
#   'mentorscore': 0,
#   'name': 'name33172b72d0b17f832aa47d577318b7f00862961e',
#   'overalexperience': 2,
#   'patronymic': 'patronymic33172b72d0b17f832aa47d577318b7f00862961e',
#   'position': 'developer',
#   'surname': 'surname33172b72d0b17f832aa47d577318b7f00862961e',
#   'wantmentee': 1},
#  {'age': 34,
#   'codinglanguages': 'java, c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '66b122ab7214ebfa2e82da9d8dcab04af0d6c841',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name66b122ab7214ebfa2e82da9d8dcab04af0d6c841',
#   'overalexperience': 0,
#   'patronymic': 'patronymic66b122ab7214ebfa2e82da9d8dcab04af0d6c841',
#   'position': 'developer',
#   'surname': 'surname66b122ab7214ebfa2e82da9d8dcab04af0d6c841',
#   'wantmentee': 1},
#  {'age': 43,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'b3efc52317471a44955801afab6d65b69af55771',
#   'institutes': 'Московский технологический университет, Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'nameb3efc52317471a44955801afab6d65b69af55771',
#   'overalexperience': 0,
#   'patronymic': 'patronymicb3efc52317471a44955801afab6d65b69af55771',
#   'position': 'developer',
#   'surname': 'surnameb3efc52317471a44955801afab6d65b69af55771',
#   'wantmentee': 1},
#  {'age': 36,
#   'codinglanguages': 'java, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '2e0d9f85d639aada7f484454f36b359066ebdec5',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name2e0d9f85d639aada7f484454f36b359066ebdec5',
#   'overalexperience': 1,
#   'patronymic': 'patronymic2e0d9f85d639aada7f484454f36b359066ebdec5',
#   'position': 'developer',
#   'surname': 'surname2e0d9f85d639aada7f484454f36b359066ebdec5',
#   'wantmentee': 1},
#  {'age': 31,
#   'codinglanguages': 'c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '0b86d6a10b4a4870ba2973509e43e0d0b46844f8',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name0b86d6a10b4a4870ba2973509e43e0d0b46844f8',
#   'overalexperience': 0,
#   'patronymic': 'patronymic0b86d6a10b4a4870ba2973509e43e0d0b46844f8',
#   'position': 'developer',
#   'surname': 'surname0b86d6a10b4a4870ba2973509e43e0d0b46844f8',
#   'wantmentee': 1},
#  {'age': 43,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '3c4c92214f362a93df2a556a7210f09fc355c6a5',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.9000000000000001,
#   'mentorscore': 0,
#   'name': 'name3c4c92214f362a93df2a556a7210f09fc355c6a5',
#   'overalexperience': 3,
#   'patronymic': 'patronymic3c4c92214f362a93df2a556a7210f09fc355c6a5',
#   'position': 'developer',
#   'surname': 'surname3c4c92214f362a93df2a556a7210f09fc355c6a5',
#   'wantmentee': 1},
#  {'age': 29,
#   'codinglanguages': 'java, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'd932244b199b7258eab4abdee21345397bbb27be',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'named932244b199b7258eab4abdee21345397bbb27be',
#   'overalexperience': 0,
#   'patronymic': 'patronymicd932244b199b7258eab4abdee21345397bbb27be',
#   'position': 'developer',
#   'surname': 'surnamed932244b199b7258eab4abdee21345397bbb27be',
#   'wantmentee': 1},
#  {'age': 27,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'a52a5b936d0d59b6f698894c9721946c83b0a452',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namea52a5b936d0d59b6f698894c9721946c83b0a452',
#   'overalexperience': 0,
#   'patronymic': 'patronymica52a5b936d0d59b6f698894c9721946c83b0a452',
#   'position': 'developer',
#   'surname': 'surnamea52a5b936d0d59b6f698894c9721946c83b0a452',
#   'wantmentee': 1},
#  {'age': 28,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '43b7c38364e72e501009a2a5dda1dcce836268ad',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name43b7c38364e72e501009a2a5dda1dcce836268ad',
#   'overalexperience': 0,
#   'patronymic': 'patronymic43b7c38364e72e501009a2a5dda1dcce836268ad',
#   'position': 'developer',
#   'surname': 'surname43b7c38364e72e501009a2a5dda1dcce836268ad',
#   'wantmentee': 1},
#  {'age': 33,
#   'codinglanguages': 'c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'b1006bd9a3cee8e04bb478c87df00ee8d949273b',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'nameb1006bd9a3cee8e04bb478c87df00ee8d949273b',
#   'overalexperience': 0,
#   'patronymic': 'patronymicb1006bd9a3cee8e04bb478c87df00ee8d949273b',
#   'position': 'developer',
#   'surname': 'surnameb1006bd9a3cee8e04bb478c87df00ee8d949273b',
#   'wantmentee': 1},
#  {'age': 30,
#   'codinglanguages': 'c/c++, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'fed9f720272007098ea9315444f4e90ead45a74a',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namefed9f720272007098ea9315444f4e90ead45a74a',
#   'overalexperience': 0,
#   'patronymic': 'patronymicfed9f720272007098ea9315444f4e90ead45a74a',
#   'position': 'developer',
#   'surname': 'surnamefed9f720272007098ea9315444f4e90ead45a74a',
#   'wantmentee': 1},
#  {'age': 32,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '173195e663d6be917dccb5123c73ef664ae37f92',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name173195e663d6be917dccb5123c73ef664ae37f92',
#   'overalexperience': 0,
#   'patronymic': 'patronymic173195e663d6be917dccb5123c73ef664ae37f92',
#   'position': 'developer',
#   'surname': 'surname173195e663d6be917dccb5123c73ef664ae37f92',
#   'wantmentee': 1},
#  {'age': 33,
#   'codinglanguages': 'java, c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'fcf72f8d18862fc7d3f1cd519e6ff90f9b5de84d',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана, Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'namefcf72f8d18862fc7d3f1cd519e6ff90f9b5de84d',
#   'overalexperience': 1,
#   'patronymic': 'patronymicfcf72f8d18862fc7d3f1cd519e6ff90f9b5de84d',
#   'position': 'developer',
#   'surname': 'surnamefcf72f8d18862fc7d3f1cd519e6ff90f9b5de84d',
#   'wantmentee': 1},
#  {'age': 44,
#   'codinglanguages': 'java, 1c',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '10f9c636408c6a96d0d3c051ffca35448e08a63d',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name10f9c636408c6a96d0d3c051ffca35448e08a63d',
#   'overalexperience': 1,
#   'patronymic': 'patronymic10f9c636408c6a96d0d3c051ffca35448e08a63d',
#   'position': 'developer',
#   'surname': 'surname10f9c636408c6a96d0d3c051ffca35448e08a63d',
#   'wantmentee': 1},
#  {'age': 33,
#   'codinglanguages': 'java, c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '30cb89624563c47bf09fd6a13431536c41c74045',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана, Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name30cb89624563c47bf09fd6a13431536c41c74045',
#   'overalexperience': 1,
#   'patronymic': 'patronymic30cb89624563c47bf09fd6a13431536c41c74045',
#   'position': 'developer',
#   'surname': 'surname30cb89624563c47bf09fd6a13431536c41c74045',
#   'wantmentee': 1},
#  {'age': 27,
#   'codinglanguages': 'c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'c1601c192516d529fb5dd7d25ee0e9d11d04f279',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет), Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namec1601c192516d529fb5dd7d25ee0e9d11d04f279',
#   'overalexperience': 0,
#   'patronymic': 'patronymicc1601c192516d529fb5dd7d25ee0e9d11d04f279',
#   'position': 'developer',
#   'surname': 'surnamec1601c192516d529fb5dd7d25ee0e9d11d04f279',
#   'wantmentee': 1},
#  {'age': 45,
#   'codinglanguages': 'java, c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '94be9d345132947a6200840ddfc68588a4820202',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name94be9d345132947a6200840ddfc68588a4820202',
#   'overalexperience': 0,
#   'patronymic': 'patronymic94be9d345132947a6200840ddfc68588a4820202',
#   'position': 'developer',
#   'surname': 'surname94be9d345132947a6200840ddfc68588a4820202',
#   'wantmentee': 1},
#  {'age': 39,
#   'codinglanguages': 'java, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '6a0c4c10ce2c26bba6d2366d22a7b646d7bbdc18',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name6a0c4c10ce2c26bba6d2366d22a7b646d7bbdc18',
#   'overalexperience': 0,
#   'patronymic': 'patronymic6a0c4c10ce2c26bba6d2366d22a7b646d7bbdc18',
#   'position': 'developer',
#   'surname': 'surname6a0c4c10ce2c26bba6d2366d22a7b646d7bbdc18',
#   'wantmentee': 1},
#  {'age': 31,
#   'codinglanguages': 'c/c++, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '712d7c9672c855a77090dd0ae910e889437b807c',
#   'institutes': 'Московский государственный технологический университет "Станкин"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.9000000000000001,
#   'mentorscore': 0,
#   'name': 'name712d7c9672c855a77090dd0ae910e889437b807c',
#   'overalexperience': 3,
#   'patronymic': 'patronymic712d7c9672c855a77090dd0ae910e889437b807c',
#   'position': 'developer',
#   'surname': 'surname712d7c9672c855a77090dd0ae910e889437b807c',
#   'wantmentee': 1},
#  {'age': 28,
#   'codinglanguages': 'java, c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'e6f303963cd6581c0e7b9893894db5d958607874',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана, Тверской государственный университет',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namee6f303963cd6581c0e7b9893894db5d958607874',
#   'overalexperience': 0,
#   'patronymic': 'patronymice6f303963cd6581c0e7b9893894db5d958607874',
#   'position': 'developer',
#   'surname': 'surnamee6f303963cd6581c0e7b9893894db5d958607874',
#   'wantmentee': 1},
#  {'age': 30,
#   'codinglanguages': 'java, c/c++, python',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '9851685f8e330dfebba942d93f95e5114188b840',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name9851685f8e330dfebba942d93f95e5114188b840',
#   'overalexperience': 0,
#   'patronymic': 'patronymic9851685f8e330dfebba942d93f95e5114188b840',
#   'position': 'developer',
#   'surname': 'surname9851685f8e330dfebba942d93f95e5114188b840',
#   'wantmentee': 1},
#  {'age': 27,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '28fa32832ef1a5d3fc77214ae9de91a30f21a733',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name28fa32832ef1a5d3fc77214ae9de91a30f21a733',
#   'overalexperience': 1,
#   'patronymic': 'patronymic28fa32832ef1a5d3fc77214ae9de91a30f21a733',
#   'position': 'developer',
#   'surname': 'surname28fa32832ef1a5d3fc77214ae9de91a30f21a733',
#   'wantmentee': 1},
#  {'age': 40,
#   'codinglanguages': 'c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'a0fb0824d0aa8b628995b5c20ee608414aa883c7',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namea0fb0824d0aa8b628995b5c20ee608414aa883c7',
#   'overalexperience': 0,
#   'patronymic': 'patronymica0fb0824d0aa8b628995b5c20ee608414aa883c7',
#   'position': 'developer',
#   'surname': 'surnamea0fb0824d0aa8b628995b5c20ee608414aa883c7',
#   'wantmentee': 1},
#  {'age': 36,
#   'codinglanguages': 'c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'c917d825abd7fd3b7c73f79e731a4be380cb693b',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namec917d825abd7fd3b7c73f79e731a4be380cb693b',
#   'overalexperience': 0,
#   'patronymic': 'patronymicc917d825abd7fd3b7c73f79e731a4be380cb693b',
#   'position': 'developer',
#   'surname': 'surnamec917d825abd7fd3b7c73f79e731a4be380cb693b',
#   'wantmentee': 1},
#  {'age': 40,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '8a1a6e653877ee938b7bc81a5a3cee58c3c04705',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name8a1a6e653877ee938b7bc81a5a3cee58c3c04705',
#   'overalexperience': 0,
#   'patronymic': 'patronymic8a1a6e653877ee938b7bc81a5a3cee58c3c04705',
#   'position': 'developer',
#   'surname': 'surname8a1a6e653877ee938b7bc81a5a3cee58c3c04705',
#   'wantmentee': 1},
#  {'age': 40,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '4f17f841fb3a503ce0b362a0bb99e5285ec2358c',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name4f17f841fb3a503ce0b362a0bb99e5285ec2358c',
#   'overalexperience': 0,
#   'patronymic': 'patronymic4f17f841fb3a503ce0b362a0bb99e5285ec2358c',
#   'position': 'developer',
#   'surname': 'surname4f17f841fb3a503ce0b362a0bb99e5285ec2358c',
#   'wantmentee': 1},
#  {'age': 27,
#   'codinglanguages': 'java, c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '7172184865c1936e79679279e03c69ed63028246',
#   'institutes': 'Московский государственный технологический университет "Станкин"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name7172184865c1936e79679279e03c69ed63028246',
#   'overalexperience': 0,
#   'patronymic': 'patronymic7172184865c1936e79679279e03c69ed63028246',
#   'position': 'developer',
#   'surname': 'surname7172184865c1936e79679279e03c69ed63028246',
#   'wantmentee': 1},
#  {'age': 40,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'ed8845f269bf6bffff0a6e1d44f7f9b9e8591942',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'nameed8845f269bf6bffff0a6e1d44f7f9b9e8591942',
#   'overalexperience': 0,
#   'patronymic': 'patronymiced8845f269bf6bffff0a6e1d44f7f9b9e8591942',
#   'position': 'developer',
#   'surname': 'surnameed8845f269bf6bffff0a6e1d44f7f9b9e8591942',
#   'wantmentee': 1},
#  {'age': 31,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '54f05d69b7c9ff1900f80946b832be7a993d9054',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name54f05d69b7c9ff1900f80946b832be7a993d9054',
#   'overalexperience': 0,
#   'patronymic': 'patronymic54f05d69b7c9ff1900f80946b832be7a993d9054',
#   'position': 'developer',
#   'surname': 'surname54f05d69b7c9ff1900f80946b832be7a993d9054',
#   'wantmentee': 1},
#  {'age': 40,
#   'codinglanguages': 'c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '405af86cc39fc30b4db36c5219e263b181abfa46',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name405af86cc39fc30b4db36c5219e263b181abfa46',
#   'overalexperience': 0,
#   'patronymic': 'patronymic405af86cc39fc30b4db36c5219e263b181abfa46',
#   'position': 'developer',
#   'surname': 'surname405af86cc39fc30b4db36c5219e263b181abfa46',
#   'wantmentee': 1},
#  {'age': 32,
#   'codinglanguages': 'c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '7d182186bf197a062220ec84490df56f534513ba',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ", (МИФИ) Московский инженерно-физический институт (государственный университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name7d182186bf197a062220ec84490df56f534513ba',
#   'overalexperience': 0,
#   'patronymic': 'patronymic7d182186bf197a062220ec84490df56f534513ba',
#   'position': 'developer',
#   'surname': 'surname7d182186bf197a062220ec84490df56f534513ba',
#   'wantmentee': 1},
#  {'age': 34,
#   'codinglanguages': 'c/c++, python, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '84abf4c82a1642ca1e417d63985e1163841ad4cb',
#   'institutes': 'University of Groningen, Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.8,
#   'mentorscore': 0,
#   'name': 'name84abf4c82a1642ca1e417d63985e1163841ad4cb',
#   'overalexperience': 2,
#   'patronymic': 'patronymic84abf4c82a1642ca1e417d63985e1163841ad4cb',
#   'position': 'developer',
#   'surname': 'surname84abf4c82a1642ca1e417d63985e1163841ad4cb',
#   'wantmentee': 1},
#  {'age': 57,
#   'codinglanguages': 'c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '2b7c704a9d9f83e732ddffd00d9e15e7aacf6586',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name2b7c704a9d9f83e732ddffd00d9e15e7aacf6586',
#   'overalexperience': 0,
#   'patronymic': 'patronymic2b7c704a9d9f83e732ddffd00d9e15e7aacf6586',
#   'position': 'developer',
#   'surname': 'surname2b7c704a9d9f83e732ddffd00d9e15e7aacf6586',
#   'wantmentee': 1},
#  {'age': 33,
#   'codinglanguages': 'java, c/c++, haskell',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'c84ea7185a6f6e2546fc1aed2c078b395a751f4c',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namec84ea7185a6f6e2546fc1aed2c078b395a751f4c',
#   'overalexperience': 0,
#   'patronymic': 'patronymicc84ea7185a6f6e2546fc1aed2c078b395a751f4c',
#   'position': 'developer',
#   'surname': 'surnamec84ea7185a6f6e2546fc1aed2c078b395a751f4c',
#   'wantmentee': 1},
#  {'age': 29,
#   'codinglanguages': 'c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '9485c79f732031450eb9d679970d39519fd9e112',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ", Национальный исследовательский ядерный университет "МИФИ"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name9485c79f732031450eb9d679970d39519fd9e112',
#   'overalexperience': 0,
#   'patronymic': 'patronymic9485c79f732031450eb9d679970d39519fd9e112',
#   'position': 'developer',
#   'surname': 'surname9485c79f732031450eb9d679970d39519fd9e112',
#   'wantmentee': 1},
#  {'age': 31,
#   'codinglanguages': 'c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '53cbfc15440ae13ed374e460798a22a73f761913',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name53cbfc15440ae13ed374e460798a22a73f761913',
#   'overalexperience': 0,
#   'patronymic': 'patronymic53cbfc15440ae13ed374e460798a22a73f761913',
#   'position': 'developer',
#   'surname': 'surname53cbfc15440ae13ed374e460798a22a73f761913',
#   'wantmentee': 1},
#  {'age': 31,
#   'codinglanguages': 'c/c++, python',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '9075564e5e32f800b24d8e06978f601963b076bc',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name9075564e5e32f800b24d8e06978f601963b076bc',
#   'overalexperience': 1,
#   'patronymic': 'patronymic9075564e5e32f800b24d8e06978f601963b076bc',
#   'position': 'developer',
#   'surname': 'surname9075564e5e32f800b24d8e06978f601963b076bc',
#   'wantmentee': 1},
#  {'age': 38,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'be1fcbb209ca51daf624dc19519486c53b4dd4d7',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namebe1fcbb209ca51daf624dc19519486c53b4dd4d7',
#   'overalexperience': 0,
#   'patronymic': 'patronymicbe1fcbb209ca51daf624dc19519486c53b4dd4d7',
#   'position': 'developer',
#   'surname': 'surnamebe1fcbb209ca51daf624dc19519486c53b4dd4d7',
#   'wantmentee': 1},
#  {'age': 26,
#   'codinglanguages': 'java, c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '9291c1710efa66cfcbda47fd1160f7dc4ee4aafb',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name9291c1710efa66cfcbda47fd1160f7dc4ee4aafb',
#   'overalexperience': 1,
#   'patronymic': 'patronymic9291c1710efa66cfcbda47fd1160f7dc4ee4aafb',
#   'position': 'developer',
#   'surname': 'surname9291c1710efa66cfcbda47fd1160f7dc4ee4aafb',
#   'wantmentee': 1},
#  {'age': 28,
#   'codinglanguages': 'java, c/c++, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '8f8d8dcf95b0a0b24eeedc39dcba644ca8bee017',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана, Национальный исследовательский технологический университет "МИСиС"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name8f8d8dcf95b0a0b24eeedc39dcba644ca8bee017',
#   'overalexperience': 0,
#   'patronymic': 'patronymic8f8d8dcf95b0a0b24eeedc39dcba644ca8bee017',
#   'position': 'developer',
#   'surname': 'surname8f8d8dcf95b0a0b24eeedc39dcba644ca8bee017',
#   'wantmentee': 1},
#  {'age': 27,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '479331251086edcde0ef0678c04c453a39a8c27a',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name479331251086edcde0ef0678c04c453a39a8c27a',
#   'overalexperience': 0,
#   'patronymic': 'patronymic479331251086edcde0ef0678c04c453a39a8c27a',
#   'position': 'developer',
#   'surname': 'surname479331251086edcde0ef0678c04c453a39a8c27a',
#   'wantmentee': 1},
#  {'age': 61,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '4c083e6e7f323e6b39fbc5bbb29c555c19cb47fa',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.8,
#   'mentorscore': 0,
#   'name': 'name4c083e6e7f323e6b39fbc5bbb29c555c19cb47fa',
#   'overalexperience': 2,
#   'patronymic': 'patronymic4c083e6e7f323e6b39fbc5bbb29c555c19cb47fa',
#   'position': 'developer',
#   'surname': 'surname4c083e6e7f323e6b39fbc5bbb29c555c19cb47fa',
#   'wantmentee': 1},
#  {'age': 38,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
# ...
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '470086653b49f7e6270193babf205c8557876c30',
#   'institutes': 'Национальный исследовательский университет "Высшая школа экономики", Московский государственный университет леса',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name470086653b49f7e6270193babf205c8557876c30',
#   'overalexperience': 0,
#   'patronymic': 'patronymic470086653b49f7e6270193babf205c8557876c30',
#   'position': 'developer',
#   'surname': 'surname470086653b49f7e6270193babf205c8557876c30',
#   'wantmentee': 1},
#  {'age': 34,
#   'codinglanguages': 'java, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '4c79797f08463abc21f12cb6d2666e3df2ab9dd9',
#   'institutes': '(НИУ ВШЭ) Национальный исследовательский университет "Высшая школа экономики", Москва, Московский авиационный институт (Национальный исследовательский университет), Московский государственный колледж информационных технологий',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name4c79797f08463abc21f12cb6d2666e3df2ab9dd9',
#   'overalexperience': 0,
#   'patronymic': 'patronymic4c79797f08463abc21f12cb6d2666e3df2ab9dd9',
#   'position': 'developer',
#   'surname': 'surname4c79797f08463abc21f12cb6d2666e3df2ab9dd9',
#   'wantmentee': 1},
#  {'age': 26,
#   'codinglanguages': 'python',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '169e6ebf50f3b25fcf69dbfe1c598832126ccd15',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name169e6ebf50f3b25fcf69dbfe1c598832126ccd15',
#   'overalexperience': 0,
#   'patronymic': 'patronymic169e6ebf50f3b25fcf69dbfe1c598832126ccd15',
#   'position': 'developer',
#   'surname': 'surname169e6ebf50f3b25fcf69dbfe1c598832126ccd15',
#   'wantmentee': 1},
#  {'age': 36,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'd8270fb6ebfa45230ddb822fed10872f94ebc5ed',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'named8270fb6ebfa45230ddb822fed10872f94ebc5ed',
#   'overalexperience': 0,
#   'patronymic': 'patronymicd8270fb6ebfa45230ddb822fed10872f94ebc5ed',
#   'position': 'developer',
#   'surname': 'surnamed8270fb6ebfa45230ddb822fed10872f94ebc5ed',
#   'wantmentee': 1},
#  {'age': 28,
#   'codinglanguages': 'java, c/c++',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'be82123405ee288ee1a4ced01f96022ea9f52adf',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namebe82123405ee288ee1a4ced01f96022ea9f52adf',
#   'overalexperience': 0,
#   'patronymic': 'patronymicbe82123405ee288ee1a4ced01f96022ea9f52adf',
#   'position': 'developer',
#   'surname': 'surnamebe82123405ee288ee1a4ced01f96022ea9f52adf',
#   'wantmentee': 1},
#  {'age': 28,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '940d6954557c1ac95d9f46ee935eb7758ef2d56c',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.7000000000000001,
#   'mentorscore': 0,
#   'name': 'name940d6954557c1ac95d9f46ee935eb7758ef2d56c',
#   'overalexperience': 1,
#   'patronymic': 'patronymic940d6954557c1ac95d9f46ee935eb7758ef2d56c',
#   'position': 'developer',
#   'surname': 'surname940d6954557c1ac95d9f46ee935eb7758ef2d56c',
#   'wantmentee': 1},
#  {'age': 37,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '7935df1de812d62cd86954859c09293050e27c67',
#   'institutes': 'Национальный исследовательский ядерный университет "МИФИ", Московский Государственнй Колледж Информатики и Права',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name7935df1de812d62cd86954859c09293050e27c67',
#   'overalexperience': 0,
#   'patronymic': 'patronymic7935df1de812d62cd86954859c09293050e27c67',
#   'position': 'developer',
#   'surname': 'surname7935df1de812d62cd86954859c09293050e27c67',
#   'wantmentee': 1},
#  {'age': 48,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '4455bff001d3d00f16e7f9c4a4254448edb656db',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.8,
#   'mentorscore': 0,
#   'name': 'name4455bff001d3d00f16e7f9c4a4254448edb656db',
#   'overalexperience': 2,
#   'patronymic': 'patronymic4455bff001d3d00f16e7f9c4a4254448edb656db',
#   'position': 'developer',
#   'surname': 'surname4455bff001d3d00f16e7f9c4a4254448edb656db',
#   'wantmentee': 1},
#  {'age': 27,
#   'codinglanguages': 'c/c++, python, haskell',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'bddc4226a0c4a0fefaa87a667892c55f3d001523',
#   'institutes': 'Санкт-Петербургский Академический университет, Московский государственный университет им. М.В.Ломоносова, Московский государственный университет им. М.В.Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namebddc4226a0c4a0fefaa87a667892c55f3d001523',
#   'overalexperience': 0,
#   'patronymic': 'patronymicbddc4226a0c4a0fefaa87a667892c55f3d001523',
#   'position': 'developer',
#   'surname': 'surnamebddc4226a0c4a0fefaa87a667892c55f3d001523',
#   'wantmentee': 1},
#  {'age': 21,
#   'codinglanguages': 'java, c/c++, python',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '9e09cbba3f44cf29d5686a349374ea6a88f21ba0',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name9e09cbba3f44cf29d5686a349374ea6a88f21ba0',
#   'overalexperience': 0,
#   'patronymic': 'patronymic9e09cbba3f44cf29d5686a349374ea6a88f21ba0',
#   'position': 'developer',
#   'surname': 'surname9e09cbba3f44cf29d5686a349374ea6a88f21ba0',
#   'wantmentee': 1},
#  {'age': 24,
#   'codinglanguages': 'c/c++, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '07f86b365dabd26fc03dd441c718b6b27fb1a04c',
#   'institutes': 'Национальный исследовательский университет "Высшая школа экономики"',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name07f86b365dabd26fc03dd441c718b6b27fb1a04c',
#   'overalexperience': 0,
#   'patronymic': 'patronymic07f86b365dabd26fc03dd441c718b6b27fb1a04c',
#   'position': 'developer',
#   'surname': 'surname07f86b365dabd26fc03dd441c718b6b27fb1a04c',
#   'wantmentee': 1},
#  {'age': 23,
#   'codinglanguages': 'python',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'a050475011c699e6058fb1d82739326506ddd970',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namea050475011c699e6058fb1d82739326506ddd970',
#   'overalexperience': 0,
#   'patronymic': 'patronymica050475011c699e6058fb1d82739326506ddd970',
#   'position': 'developer',
#   'surname': 'surnamea050475011c699e6058fb1d82739326506ddd970',
#   'wantmentee': 1},
#  {'age': 22,
#   'codinglanguages': 'java, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '6c76039da89534f2b5c81e11e8ed0769bf5599ca',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет), ',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name6c76039da89534f2b5c81e11e8ed0769bf5599ca',
#   'overalexperience': 0,
#   'patronymic': 'patronymic6c76039da89534f2b5c81e11e8ed0769bf5599ca',
#   'position': 'developer',
#   'surname': 'surname6c76039da89534f2b5c81e11e8ed0769bf5599ca',
#   'wantmentee': 1},
#  {'age': 24,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '1bf524ae55a6b173479b5363875bc25e735d9025',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name1bf524ae55a6b173479b5363875bc25e735d9025',
#   'overalexperience': 0,
#   'patronymic': 'patronymic1bf524ae55a6b173479b5363875bc25e735d9025',
#   'position': 'developer',
#   'surname': 'surname1bf524ae55a6b173479b5363875bc25e735d9025',
#   'wantmentee': 1},
#  {'age': 42,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '95e4b2c146f6c4a58b94a588c47d172d97cb0494',
#   'institutes': 'Московский государственный университет им. М.В.Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name95e4b2c146f6c4a58b94a588c47d172d97cb0494',
#   'overalexperience': 0,
#   'patronymic': 'patronymic95e4b2c146f6c4a58b94a588c47d172d97cb0494',
#   'position': 'developer',
#   'surname': 'surname95e4b2c146f6c4a58b94a588c47d172d97cb0494',
#   'wantmentee': 1},
#  {'age': 24,
#   'codinglanguages': 'c/c++, python, c#',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '2c2140e4f921f5975aa7f2eed5ff3a85b1f79535',
#   'institutes': 'Московский государственный университет им. М.В.Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name2c2140e4f921f5975aa7f2eed5ff3a85b1f79535',
#   'overalexperience': 0,
#   'patronymic': 'patronymic2c2140e4f921f5975aa7f2eed5ff3a85b1f79535',
#   'position': 'developer',
#   'surname': 'surname2c2140e4f921f5975aa7f2eed5ff3a85b1f79535',
#   'wantmentee': 1},
#  {'age': 22,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'cd98f4b083bc6bf25e06d624a6084e7854e92bc9',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namecd98f4b083bc6bf25e06d624a6084e7854e92bc9',
#   'overalexperience': 0,
#   'patronymic': 'patronymiccd98f4b083bc6bf25e06d624a6084e7854e92bc9',
#   'position': 'developer',
#   'surname': 'surnamecd98f4b083bc6bf25e06d624a6084e7854e92bc9',
#   'wantmentee': 1},
#  {'age': 30,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '136dbaef5f2f715e6c7d2886e67e722fa0e35250',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name136dbaef5f2f715e6c7d2886e67e722fa0e35250',
#   'overalexperience': 0,
#   'patronymic': 'patronymic136dbaef5f2f715e6c7d2886e67e722fa0e35250',
#   'position': 'developer',
#   'surname': 'surname136dbaef5f2f715e6c7d2886e67e722fa0e35250',
#   'wantmentee': 1},
#  {'age': 32,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'b3af89a65808fe9f2d7f4d119e5e9e0c7446f430',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'nameb3af89a65808fe9f2d7f4d119e5e9e0c7446f430',
#   'overalexperience': 0,
#   'patronymic': 'patronymicb3af89a65808fe9f2d7f4d119e5e9e0c7446f430',
#   'position': 'developer',
#   'surname': 'surnameb3af89a65808fe9f2d7f4d119e5e9e0c7446f430',
#   'wantmentee': 1},
#  {'age': 28,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'cfde9fe5a80c9e86bf04c5aed972b2f189080a35',
#   'institutes': 'Московский государственный университет им. М.В.Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namecfde9fe5a80c9e86bf04c5aed972b2f189080a35',
#   'overalexperience': 0,
#   'patronymic': 'patronymiccfde9fe5a80c9e86bf04c5aed972b2f189080a35',
#   'position': 'developer',
#   'surname': 'surnamecfde9fe5a80c9e86bf04c5aed972b2f189080a35',
#   'wantmentee': 1},
#  {'age': 31,
#   'codinglanguages': 'java',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': '5e5893ef17c0aa32d1e68a4ae2bb5a13e72ae722',
#   'institutes': 'Московский государственный университет им. М.В. Ломоносова',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'name5e5893ef17c0aa32d1e68a4ae2bb5a13e72ae722',
#   'overalexperience': 0,
#   'patronymic': 'patronymic5e5893ef17c0aa32d1e68a4ae2bb5a13e72ae722',
#   'position': 'developer',
#   'surname': 'surname5e5893ef17c0aa32d1e68a4ae2bb5a13e72ae722',
#   'wantmentee': 1},
#  {'age': 33,
#   'codinglanguages': 'c/c++, 1c',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'f7df7004bd4232bf1f4d3dddd294af38f5bfb053',
#   'institutes': 'Московский авиационный институт (Национальный исследовательский университет)',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 1.0,
#   'mentorscore': 0,
#   'name': 'namef7df7004bd4232bf1f4d3dddd294af38f5bfb053',
#   'overalexperience': 4,
#   'patronymic': 'patronymicf7df7004bd4232bf1f4d3dddd294af38f5bfb053',
#   'position': 'developer',
#   'surname': 'surnamef7df7004bd4232bf1f4d3dddd294af38f5bfb053',
#   'wantmentee': 1},
#  {'age': 18,
#   'codinglanguages': '',
#   'currentcompanyexperience': 3,
#   'department': 'development',
#   'id': 'f9e5c5595e00ead1889358d39013325849e1bbe0',
#   'institutes': 'Московский государственный технический университет имени Н.Э.Баумана, ',
#   'ismentee': 0,
#   'ismentor': 0,
#   'maxmentee': 3,
#   'menteeid': '',
#   'menteescore': 0,
#   'mentorid': '',
#   'mentorpossibility': 0.6000000000000001,
#   'mentorscore': 0,
#   'name': 'namef9e5c5595e00ead1889358d39013325849e1bbe0',
#   'overalexperience': 0,
#   'patronymic': 'patronymicf9e5c5595e00ead1889358d39013325849e1bbe0',
#   'position': 'developer',
#   'surname': 'surnamef9e5c5595e00ead1889358d39013325849e1bbe0',
#   'wantmentee': 1}]
